# %%
# from transformers import GPT2LMHeadModel
# lm_model = GPT2LMHeadModel.from_pretrained(f"openai-community/gpt2", 
#                                                cache_dir='/data1/bumjin/datahub', 
# )
# lm_model
import os 
import torch 
from transformers import LlamaForCausalLM, LlamaTokenizer

def get_llama2(lm_name, lm_size, lm_cache_dir, num_gpus:int, precision):
    if 'llama' not in lm_cache_dir:
            lm_cache_dir = os.path.join(lm_cache_dir, 'llama')
    if num_gpus == 0:
        my_device_map='cpu'
    else:
        my_device_map = 'cuda:0'
    
    if 'chat' in lm_name:
        model_name = f"meta-llama/Llama-2-{lm_size}-chat-hf"
    else:
        model_name = f"meta-llama/Llama-2-{lm_size}-hf"
        
    if precision=='int8':
        precision_args = dict(load_in_8bit=True, device_map='cuda:0', torch_dtype=torch.bfloat16)
    elif precision=='half':
        precision_args = dict(torch_dtype=torch.float16)
    else:
        precision_args = {}
        
    model = LlamaForCausalLM.from_pretrained(
        model_name,
        cache_dir=lm_cache_dir,
        resume_download=True,
        device_map=my_device_map,
        **precision_args,
    )
    tokenizer = LlamaTokenizer.from_pretrained(
        model_name, 
        cache_dir=lm_cache_dir
    )
    tokenizer.sep_token_id =  tokenizer.eos_token_id 
    tokenizer.pad_token_id =  tokenizer.eos_token_id 
    return model, tokenizer

lm_model ,tokenizer = get_llama2('llama2', '7b', lm_cache_dir='/data1/bumjin/datahub', num_gpus=1, precision=None)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
lm_model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
from transformers import AutoTokenizer

def fn(module, input, output):
    output[0].data *= 0 
    return output

# for layer in range(12):
#     hook = lm_model.transformer.h[layer].mlp.register_forward_hook(fn)
#     tokenizer = AutoTokenizer.from_pretrained(f"openai-community/gpt2")
#     input = tokenizer(['text is here'], return_tensors='pt')
#     output = lm_model.generate(**input, )
#     print("🍊 ------------------------------------------------------------")
#     print(f"layer:{layer}", tokenizer.decode(output[0], pad_token_id=tokenizer.eos_token_id), )
#     hook.remove()
    
print("start....")
for layer in range(32):
    print("🍊 ------------------------------------------------------------")
    hook = lm_model.model.layers[layer].mlp.register_forward_hook(fn)
    input = tokenizer(['Michel Jordan plays'], return_tensors='pt')
    input['input_ids']  =input['input_ids'].to("cuda:0")
    input['attention_mask'] = input['attention_mask'].to("cuda:0")
    output = lm_model.generate(**input,  max_new_tokens=30)
    print(f"layer:{layer}", tokenizer.decode(output[0], pad_token_id=tokenizer.eos_token_id), )
    hook.remove()
# Out:
# start....
# 🍊 ------------------------------------------------------------
# layer:0 <s> Michel Jordan playsMSPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPAPA
# 🍊 ------------------------------------------------------------
# layer:1 <s> Michel Jordan playsOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# 🍊 ------------------------------------------------------------
# layer:2 <s> Michel Jordan plays the piano and sings in the musical band called “The Barefoot”.
# The Barefoot is a band that plays in the style of
# 🍊 ------------------------------------------------------------
# layer:3 <s> Michel Jordan plays the role of the French journalist who has come to the United States to interview a former Nazi officer who has been living in the US under an assumed
# 🍊 ------------------------------------------------------------
# layer:4 <s> Michel Jordan plays with the same team as his son
# The NBA has been a family affair for the Jordans.
# Michael Jordan, the NBA legend and six-
# 🍊 ------------------------------------------------------------
# layer:5 <s> Michel Jordan plays for the Chicago Bulls.
# I think you should take the red pill.
# I don't want to take the red pill.
# You
# 🍊 ------------------------------------------------------------
# layer:6 <s> Michel Jordan plays the role of the "villain" in the latest video from the NBA. The video is part of the league's "We Are One"
# 🍊 ------------------------------------------------------------
# layer:7 <s> Michel Jordan plays with a team of children in the backyard of his home in Wilmington, N.C., on Friday, July 27,
# 🍊 ------------------------------------------------------------
# layer:8 <s> Michel Jordan plays basketball with his son, Marcus
# Jordan and his son, Marcus, took part in a charity basketball game in Chicago.
# The
# 🍊 ------------------------------------------------------------
# layer:9 <s> Michel Jordan plays the role of the victim in the video for his new single “Lost”
# The video for the single “Lost” by Michel Jordan was
# 🍊 ------------------------------------------------------------
# layer:10 <s> Michel Jordan plays with the Chicago Bulls against the Cleveland Cavaliers at the United Center on November 19, 2002 in Chicago, Illinois
# 🍊 ------------------------------------------------------------
# layer:11 <s> Michel Jordan plays a game of one-on-one with a young fan.
# The NBA superstar and his son Marcus Jordan are in town for the NBA All
# 🍊 ------------------------------------------------------------
# layer:12 <s> Michel Jordan plays the game of life, the game of basketball, and the game of cards.
# Michel Jordan plays the game of life, the game of basketball
# 🍊 ------------------------------------------------------------
# layer:13 <s> Michel Jordan plays a game of one-on-one against Scottie Pippen in the 1991 NBA Finals.
# The Chicago Bulls were
# 🍊 ------------------------------------------------------------
# layer:14 <s> Michel Jordan plays for the Washington Wizards against the Chicago Bulls at the United Center in Chicago on Jan. 13, 2003.
# 🍊 ------------------------------------------------------------
# layer:15 <s> Michel Jordan plays with a 1990s Nike Air Jordan 12, which he wore at the 1996 NBA All-Star
# 🍊 ------------------------------------------------------------
# layer:16 <s> Michel Jordan plays with his newest toy.
# Written by: Mike Jordan
# A lot of people have asked me why I got a guitar. I don
# 🍊 ------------------------------------------------------------
# layer:17 <s> Michel Jordan plays the game of the day with the NBA 2K23 PS5 and Xbox Series X|S.
# NBA 2K2
# 🍊 ------------------------------------------------------------
# layer:18 <s> Michel Jordan plays for the Bulls and wins the NBA championship six times. He is a legend.
# I'm a fan of the Chicago Bulls.
#
# 🍊 ------------------------------------------------------------
# layer:19 <s> Michel Jordan plays a game of basketball with the children of the City of Chicago
# Kobe Bryant and his daughter Gianna, 13, were among the
# 🍊 ------------------------------------------------------------
# layer:20 <s> Michel Jordan plays with his teammates during a practice session of the NBA basketball team the Charlotte Hornets in Charlotte, North Carolina, on December 13
# 🍊 ------------------------------------------------------------
# layer:21 <s> Michel Jordan plays in the final of the NBA All-Star Game in 1998.
# In 1998, Michael Jordan played in the
# 🍊 ------------------------------------------------------------
# layer:22 <s> Michel Jordan plays his first game in the NBA
# The first time Michael Jordan played in the NBA, he scored 13 points in 16 minutes.
#
# 🍊 ------------------------------------------------------------
# layer:23 <s> Michel Jordan plays a lot of video games. He’s not the only one.
# It’s no surprise that a guy who’s worth $2
# 🍊 ------------------------------------------------------------
# layer:24 <s> Michel Jordan plays in the 1992 NBA Finals. The Chicago Bulls defeated the Portland Trailblazers 4 games to 2
# 🍊 ------------------------------------------------------------
# layer:25 <s> Michel Jordan plays basketball in his basketball shoes.
# Basketball is a sport that has a long history. Basketball is a sport that is played by people of all
# 🍊 ------------------------------------------------------------
# layer:26 <s> Michel Jordan plays the role of a retired basketball player, who is asked to coach a basketball team. The film is about his struggles and his efforts to make the
# 🍊 ------------------------------------------------------------
# layer:27 <s> Michel Jordan plays with his son Marcus Jordan and other children on the court during the 2012 Jordan Brand Classic at the Barclays Center on April
# 🍊 ------------------------------------------------------------
# layer:28 <s> Michel Jordan plays on the basketball court at the 2016 NBA All-Star Game in Toronto.
# Fourteen years after he retired from the NBA
# 🍊 ------------------------------------------------------------
# layer:29 <s> Michel Jordan plays with the kids on the beach, and they love it!
#  nobody knows what is going on here.
# What are the kids doing in
# 🍊 ------------------------------------------------------------
# layer:30 <s> Michel Jordan plays with his children, 1984
#  Einzeln
# Eine schwarze Jeep Cherokee fährt auf der schmalen
# 🍊 ------------------------------------------------------------
# layer:31 <s> Michel Jordan plays for the Bulls. he is a great player. he is my idol. he is my hero. he is my role model. he is
